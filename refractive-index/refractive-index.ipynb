# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from IPython.core.display import HTML

# Center plots
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# First we read the index.

# %%
index = pd.read_excel('refractive-index.xlsx', sheet_name='index', index_col='id')
index.tail()
# Out:
#               sheet                                          reference
# id
# 20  ethyl_acetate_1  https://pubs.acs.org/doi/10.1021/acs.jced.5b00018
# 21        glucose_2  https://opg.optica.org/ao/abstract.cfm?URI=ao-...
# 22        glucose_3  https://www.researchgate.net/publication/26794...
# 23        sucrose_3  https://faculty.weber.edu/ewalker/Chem2990/Che...
# 24            ipa_1       https://pubs.acs.org/doi/10.1021/je60014a011

# %% [markdown]
# Now we plot each sheet in the index.

# %%
def PlotSheet(sheet, label):
    df = pd.read_excel('refractive-index.xlsx', sheet_name=sheet)
    ax.plot(df.tds, df.n, label=label)

# Create the figure
fig, ax = plt.subplots(figsize=(9,9))
fig.patch.set_facecolor('white')

# Sheets used in plot
sheets_labels = [('sucrose_1', 'Sucrose'),
                 ('glucose_3', 'Glucose'),
                 ('glycerol_1', 'Glycerol'),
                 ('propylene_glycol_1', 'Propylene glycol'),
                 ('ethylene_glycol_2', 'Ethylene glycol'),
                 ('ipa_1', 'Isopropanol'),
                 ('ethanol_3', 'Ethanol'),
                 ('methanol_2', 'Methanol')]

# Plot the sheets
for sheet, label in sheets_labels:
    PlotSheet(sheet, label)

# Set axis labels
ax.set_xlabel('Concentration in Water (% w/w)')
ax.set_ylabel('Refractive Index')

# Add legend
ax.legend()
